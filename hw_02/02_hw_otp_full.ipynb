# %%
import pandas as pd

# %%
import time
from tqdm import tqdm
for i in tqdm(range(10000)):
    time.sleep(0.1)

# %%
from tqdm import tqdm_notebook
for i in tqdm_notebook(range(10000)):
    if i % 100 == 0:
        print(i)
    time.sleep(0.1)

# %%
# считаем описание данных
df = pd.read_csv('02_otp_desc.csv', sep=';').loc[:,'ПОЛЕ':'ОПИСАНИЕ']

# %%
df
# Out:
#                           ПОЛЕ  \
# 0                 AGREEMENT_RK
# 1                       TARGET
# 2                          AGE
# 3            SOCSTATUS_WORK_FL
# 4            SOCSTATUS_PENS_FL
# 5                       GENDER
# 6                  CHILD_TOTAL
# 7                   DEPENDANTS
# 8                    EDUCATION
# 9               MARITAL_STATUS
# 10                GEN_INDUSTRY
# 11                   GEN_TITLE
# 12                ORG_TP_STATE
# 13             ORG_TP_FCAPITAL
# 14                     JOB_DIR
# 15               FAMILY_INCOME
# 16             PERSONAL_INCOME
# 17        REG_ADDRESS_PROVINCE
# 18       FACT_ADDRESS_PROVINCE
# 19     POSTAL_ADDRESS_PROVINCE
# 20                 TP_PROVINCE
# 21                   REGION_NM
# 22                 REG_FACT_FL
# 23                FACT_POST_FL
# 24                 REG_POST_FL
# 25            REG_FACT_POST_FL
# 26         REG_FACT_POST_TP_FL
# 27              FL_PRESENCE_FL
# 28                    OWN_AUTO
# 29                 AUTO_RUS_FL
# 30              HS_PRESENCE_FL
# 31             COT_PRESENCE_FL
# 32             GAR_PRESENCE_FL
# 33            LAND_PRESENCE_FL
# 34                      CREDIT
# 35                        TERM
# 36                 FST_PAYMENT
# 37              DL_DOCUMENT_FL
# 38             GPF_DOCUMENT_FL
# 39            FACT_LIVING_TERM
# 40                   WORK_TIME
# 41               FACT_PHONE_FL
# 42                REG_PHONE_FL
# 43                GEN_PHONE_FL
# 44              LOAN_NUM_TOTAL
# 45             LOAN_NUM_CLOSED
# 46               LOAN_NUM_PAYM
# 47                LOAN_DLQ_NUM
# 48                LOAN_MAX_DLQ
# 49            LOAN_AVG_DLQ_AMT
# 50            LOAN_MAX_DLQ_AMT
# 51  PREVIOUS_CARD_NUM_UTILIZED
#
#                                              ОПИСАНИЕ
# 0          уникальный идентификатор объекта в выборке
# 1   целевая переменная:отклик на маркетинговую кам...
# 2                                     возраст клиента
# 3   социальный статус клиента относительно работы ...
# 4   социальный статус клиента относительно пенсии ...
# 5                                         пол клиента
# 6                            количество детей клиента
# 7                       количество иждивенцев клиента
# 8                                         образование
# 9                                  семейное положение
# 10                             отрасль работы клиента
# 11                                          должность
# 12                       форма собственности компании
# 13                  отношение к иностранному капиталу
# 14          направление деятельности в нутри компании
# 15               семейный доход (несколько категорий)
# 16                    личный доход клиента (в рублях)
# 17                        область регистрации клиента
# 18            область фактического пребывания клиента
# 19                             почтовый адрес область
# 20  область торговой точки, где клиент брал послед...
# 21                                          регион РФ
# 22  адрес регистрации и адрес фактического пребыва...
# 23  адрес фактического пребывания клиента и его по...
# 24  адрес регистрации клиента и его почтовый адрес...
# 25  почтовый, фактический и адрес регистрации совп...
# 26  область регистрации, фактического пребывания, ...
# 27  наличие в собственности квартиры (1 - есть, 0 ...
# 28                кол-во автомобилей в собственности
# 29  наличие в собственности автомобиля российского...
# 30  наличие в собственности загородного дома (1 - ...
# 31  наличие в собственности котеджа (1 - есть, 0 -...
# 32  наличие в собственности гаража (1 - есть, 0 - ...
# 33  наличие в собственности земельного участка (1 ...
# 34        сумма последнего кредита клиента (в рублях)
# 35                                       срок кредита
# 36                    первоначальный взнос (в рублях)
# 37  в анкете клиент указал водительское удостовере...
# 38  в анкете клиен указал ГПФ (1 - указал, 0 - не ...
# 39  количество месяцев проживания по месту фактиче...
# 40          время работы на текущем месте (в месяцах)
# 41  наличие в заявке телефона по фактическому мест...
# 42     наличие в заявке телефона по месту регистрации
# 43                 наличие в заявке рабочего телефона
# 44                            количество ссуд клиента
# 45                 количество погашенных ссуд клиента
# 46         количество платежей, которые сделал клиент
# 47          количество просрочек, допущенных клиентом
# 48  номер максимальной просрочки, допущенной клиентом
# 49                 средняя сумма просрочки (в рублях)
# 50            максимальная сумма просрочки (в рублях)
# 51  количество уже утилизированных карт ( если пус...

# %%
# считаем все-все данные

# %%
train = pd.read_csv('02_otp_train.csv', sep=';')

# %%
train.shape
# Out:
# (15223, 52)

# %%
test = pd.read_csv('02_otp_test.csv', sep=';')

# %%
test.shape
# Out:
# (14910, 51)

# %%
# отделим таргет от TRAIN-а

# %%
y = train['TARGET']

# %%
train = train.drop('TARGET', axis=1)

# %%
# соеденим train и test

# %%
all_data = pd.concat([train, test])
all_data.head()
# Out:
#    AGREEMENT_RK  AGE  SOCSTATUS_WORK_FL  SOCSTATUS_PENS_FL  GENDER  \
# 0      59910150   49                  1                  0       1
# 1      59910230   32                  1                  0       1
# 2      59910525   52                  1                  0       1
# 3      59910803   39                  1                  0       1
# 4      59911781   30                  1                  0       0
#
#    CHILD_TOTAL  DEPENDANTS            EDUCATION  MARITAL_STATUS  \
# 0            2           1  Среднее специальное  Состою в браке
# 1            3           3              Среднее  Состою в браке
# 2            4           0     Неполное среднее  Состою в браке
# 3            1           1               Высшее  Состою в браке
# 4            0           0              Среднее  Состою в браке
#
#                 GEN_INDUSTRY            ...             REG_PHONE_FL  \
# 0                   Торговля            ...                        0
# 1                   Торговля            ...                        0
# 2  Информационные технологии            ...                        0
# 3                Образование            ...                        1
# 4     Государственная служба            ...                        0
#
#   GEN_PHONE_FL LOAN_NUM_TOTAL LOAN_NUM_CLOSED LOAN_NUM_PAYM LOAN_DLQ_NUM  \
# 0            1              1               1             6            2
# 1            1              1               1             6            1
# 2            1              2               1            11            0
# 3            1              1               1             6            3
# 4            1              2               1            16            2
#
#   LOAN_MAX_DLQ  LOAN_AVG_DLQ_AMT LOAN_MAX_DLQ_AMT PREVIOUS_CARD_NUM_UTILIZED
# 0            1              1580             1580                        NaN
# 1            1              4020             4020                        NaN
# 2            0                 0                0                        NaN
# 3            1  1589,92333333333             1590                        NaN
# 4            1           1152,15             2230                        NaN
#
# [5 rows x 51 columns]

# %%
# необходимо удалить индекс, 
# у нас есть 0-строка в train и 0-строка в test (и так далее 1,2,3,4)
# если мы просто объеденим - у нас сохранятся индексы
# мы же просто уберем индекс и автоматически создастся новый индекс, сквозной и уникальный
all_data = all_data.reset_index(drop=True)

# %%
# посмотрим типы данных и их заполняемость

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 51 columns):
# AGREEMENT_RK                  30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null object
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null object
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null object
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null object
# LOAN_MAX_DLQ_AMT              30133 non-null object
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# dtypes: float64(2), int64(31), object(18)
# memory usage: 11.7+ MB

# %%
# Видим, что часть данных - object, скорее всего строки.
# Давайте выведем эти значения для каждого столбца

# %%
for i in all_data.columns: # перебираем все столбцы
    if str(all_data[i].dtype) == 'object': # если тип столбца - object
        print(i) # выводим название столбца
        print(set(all_data[i])) # выводим все его значения (но делаем set - чтоб значения не повторялись)
        print() # выводим пустую строку
# Out:
# EDUCATION
# {'Среднее', 'Неоконченное высшее', 'Два и более высших образования', 'Высшее', 'Ученая степень', 'Неполное среднее', 'Среднее специальное'}
#
# MARITAL_STATUS
# {'Состою в браке', 'Разведен(а)', 'Вдовец/Вдова', 'Гражданский брак', 'Не состоял в браке'}
#
# GEN_INDUSTRY
# {nan, 'Страхование', 'Маркетинг', 'Ресторанный бизнес/Общественное питание', 'ЧОП/Детективная д-ть', 'Банк/Финансы', 'Торговля', 'Образование', 'Юридические услуги/нотариальные услуги', 'Другие сферы', 'Энергетика', 'Химия/Парфюмерия/Фармацевтика', 'Информационные услуги', 'Металлургия/Промышленность/Машиностроение', 'Салоны красоты и здоровья', 'СМИ/Реклама/PR-агенства', 'Управляющая компания', 'Недвижимость', 'Транспорт', 'Нефтегазовая промышленность', 'Государственная служба', 'Логистика', 'Развлечения/Искусство', 'Здравоохранение', 'Сельское хозяйство', 'Строительство', 'Наука', 'Подбор персонала', 'Коммунальное хоз-во/Дорожные службы', 'Информационные технологии', 'Сборочные производства', 'Туризм'}
#
# GEN_TITLE
# {nan, 'Работник сферы услуг', 'Другое', 'Служащий', 'Рабочий', 'Индивидуальный предприниматель', 'Руководитель низшего звена', 'Военнослужащий по контракту', 'Высококвалифиц. специалист', 'Специалист', 'Руководитель высшего звена', 'Партнер', 'Руководитель среднего звена'}
#
# ORG_TP_STATE
# {nan, 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Индивидуальный предприниматель', 'Государственная комп./учреж.', 'Частная компания'}
#
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
# JOB_DIR
# {nan, 'Реклама и маркетинг', 'Вспомогательный техперсонал', 'Служба безопасности', 'Бухгалтерия, финансы, планир.', 'Участие в основ. деятельности', 'Адм-хоз. и трансп. службы', 'Снабжение и сбыт', 'Кадровая служба и секретариат', 'Юридическая служба', 'Пр-техн. обесп. и телеком.'}
#
# FAMILY_INCOME
# {'до 5000 руб.', 'свыше 50000 руб.', 'от 20000 до 50000 руб.', 'от 10000 до 20000 руб.', 'от 5000 до 10000 руб.'}
#
# PERSONAL_INCOME
# {'6359', '16200', '7260', '9860', '4750', '9400', '67000', '6600', '2776', '24000', '5900', '7250', '77000', '5425', '3800', '26800', '18800', '29500', '8900', '16107,47', '42500', '10600', '14358', '7350', '11900', '7050', '16600', '10800', '14600', '6100', '94000', '5000', '5200', '3400', '5230', '13300', '15380', '24500', '17700', '250000', '7640', '100000', '14000', '9600', '12450', '17200', '12600', '5460', '230000', '4300', '16900', '22000', '7170,08', '7100', '8060', '20880', '14300', '34000', '13000', '12800', '4340', '5173', '15200', '18700', '7082', '2300', '8250', '41000', '7600', '29000', '6270', '38600', '16100', '17400', '15900', '10500', '42000', '19500', '5100', '11600', '14700', '7400', '7850', '8000', '18000', '5350', '19000', '4900', '9300', '5890', '8350', '12900', '7300', '8700', '17900', '7330', '4887', '9628', '70000', '4860', '40000', '12700', '9700', '5400', '8030', '6800', '9000', '39000', '9200', '8075', '45900', '8400', '7200', '2000', '21500', '13150', '13100', '7380', '4704', '4200', '41900', '60000', '7220', '13600', '15939', '20000', '4800', '22500', '5300', '28470', '13000000', '32640', '5790', '3100', '3900', '7460', '8726', '24', '16050', '17300', '12000', '7800', '30600', '13900', '57000', '3300', '17600', '24800', '158000', '6299,19', '4500', '13160', '16700', '11700', '6300', '5582', '6500', '25500', '4400', '7550', '11300', '20646,16', '220000', '14200', '14800', '58640', '19200', '170000', '4760', '13700', '16800', '27300', '13400', '2500', '4700', '50000', '5446', '11400', '7830', '14900', '12500', '36000', '5120', '65000', '80000', '11500', '8300', '67700', '34500', '10400', '3500', '15400', '18250', '22180', '13500', '15700', '13200', '68000', '75000', '20600', '4950', '53000', '35500', '21800', '5600', '5360', '47000', '6180', '5380', '10100', '22565', '6825', '15560', '4250', '6524', '26000', '12400', '6650', '90000', '120000', '20500', '4600', '7251', '29400', '53500', '9900', '37000', '8100', '3700', '15000', '8066', '5339', '46000', '43000', '5966', '35000', '11200', '14500', '17000', '8800', '15750', '22955', '2680', '11000', '17404', '19600', '8600', '4590', '13800', '9340', '38000', '25000', '4550', '45000', '29800', '15800', '11640', '18100', '10000', '6000', '10700', '4000', '4480', '200000', '6700', '10200', '4330', '17500', '19800', '54000', '12200', '49000', '19700', '5085', '23800', '8200', '7700', '55000', '3000', '25800', '19300', '5750', '24400', '6900', '18200', '5680', '5050', '7500', '5280', '5800', '31000', '15600', '5860', '8500', '12100', '6608', '14120', '26500', '9330', '7340', '7900', '4850', '9500', '48000', '5500', '4100', '3200', '6400', '16500', '8750', '9750', '22120', '7000', '5450', '18600', '51000', '7101', '6350', '150000', '2100', '13450', '6200', '6670', '6780', '9100', '10900', '9240', '7780', '32000', '17800', '15300', '92000', '32500', '15500', '23100', '160000', '3600', '13650', '1950', '18500', '10300', '12300', '44000', '28300', '2800', '11800', '4360', '21000', '12650', '4515', '28000', '130000', '23000', '18300', '30000', '27000', '5088', '52000', '4680', '7650', '33000', '23500', '16300', '27200', '9800', '56000', '4530', '42145', '110000', '21300', '9640', '5700', '16000'}
#
# REG_ADDRESS_PROVINCE
# {'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Коми-Пермяцкий АО', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Кабардино-Балкария', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Ленинградская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Московская область', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Северная Осетия', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Ямало-Ненецкий АО', 'Челябинская область', 'Эвенкийский АО', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Дагестан', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Карачаево-Черкесия', 'Хакасия', 'Агинский Бурятский АО', 'Новосибирская область', 'Псковская область', 'Саратовская область', 'Ростовская область', 'Якутия', 'Ставропольский край', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Усть-Ордынский Бурятский АО', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# FACT_ADDRESS_PROVINCE
# {'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Коми-Пермяцкий АО', 'Чечня', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Кабардино-Балкария', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Ленинградская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Московская область', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Северная Осетия', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Ямало-Ненецкий АО', 'Челябинская область', 'Эвенкийский АО', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Дагестан', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Карачаево-Черкесия', 'Хакасия', 'Агинский Бурятский АО', 'Новосибирская область', 'Псковская область', 'Саратовская область', 'Ростовская область', 'Якутия', 'Ставропольский край', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Усть-Ордынский Бурятский АО', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# POSTAL_ADDRESS_PROVINCE
# {'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Коми-Пермяцкий АО', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Кабардино-Балкария', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Ленинградская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Московская область', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Северная Осетия', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Ямало-Ненецкий АО', 'Челябинская область', 'Эвенкийский АО', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Дагестан', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Карачаево-Черкесия', 'Хакасия', 'Агинский Бурятский АО', 'Новосибирская область', 'Псковская область', 'Саратовская область', 'Ростовская область', 'Якутия', 'Ставропольский край', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Усть-Ордынский Бурятский АО', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# TP_PROVINCE
# {nan, 'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Свердловская область', 'Кабардино-Балкария', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Челябинская область', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Новосибирская область', 'Ставропольский край', 'Саратовская область', 'Ростовская область', 'Псковская область', 'Якутия', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# REGION_NM
# {nan, 'СЕВЕРО-ЗАПАДНЫЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ВОСТОЧНО-СИБИРСКИЙ', 'ЮЖНЫЙ', 'ПРИВОЛЖСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ДАЛЬНЕВОСТОЧНЫЙ', 'УРАЛЬСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1'}
#
# CREDIT
# {'7151', '14927,83', '32391', '9003', '20292', '10120', '11471', '5742', '12506', '20498', '17895', '11434', '37857,2', '19295', '9669', '22298', '9846', '15420,3', '90200', '12077', '48900', '6188', '16420', '16501', '21586', '20701', '20253', '10570', '7819', '19648', '18268', '12967', '27016', '18123', '39980', '10616', '23711', '16583', '18676', '5879', '17186', '8007', '14447', '23197', '7115', '5719', '3858', '19478', '7495', '5457', '22106', '7908,1', '24145', '8010', '12240', '23760', '7348', '21640', '26543', '15148', '33573', '9045', '4336', '9769', '3286', '13715', '14180', '5258', '6449', '11277', '15571', '13165,61', '26848', '11955', '21935', '2790', '7999', '21658', '9924', '10792', '13443', '15945', '10981,82', '11545', '29304,3', '6196', '27250', '23663', '9754', '3822', '25020', '15434,3', '5723,84', '14696', '31431', '35897', '38120', '15975', '13300', '19380', '5409', '17690', '26361', '21994', '18048', '8156', '11599', '3995', '24475', '11075', '13999,92', '5928,1', '99540', '24630', '7514', '4300', '27634', '3661,01', '18572,5', '18605', '2135,14', '17111', '17789', '14688', '25587', '14207,1', '
698,46', '5577,92', '2539,91', '1245,94', '1580', '2503,19', '1942,72', '840,4', '3180', '2676,24', '2058,71', '1527,19', '3900', '2250,56', '717,87', '2173,43', '869,26', '1434,4', '1747,33', '3300', '979,63', '2509,38', '1242,57', '2425', '6490', '1093,75', '1733,88', '823,54', '1300', '908,78', '2642,83', '1686,92', '1344,33', '1004,8', '1538,69', '5603,82', '1408,73', '572,22', '3013,9', '958,76', '2499,82', '4055,03', '2490', '947,57', '1851,55', '1408,53', '976,68', '2598,9', '1896,24', '791,56', '820', '616,06', '0', '1375,39', '1547,02', '2010', '828,51', '1739,33', '1319,56', '1142,83', '919,88', '1740', '861,56', '1220', '865,03', '51,8', '2193,63', '1180,87', '2742,25', '1266,34', '1094,85', '2157,89', '3140', '2247,51', '730', '840', '1190', '4650', '542', '410,6', '5076,65', '866', '1120,93', '1145,38', '1498,26', '806,19', '3355,19', '2656,68', '956,1', '2779,29', '775,86', '9840', '3303,2', '2176,36', '7620', '900', '2349,51', '2410', '620,22', '1563,45', '4820', '2740', '2239,37', '1606,38', '3780', '1068,72', '518,9', '367,35', '4450', '2160', '578,06', '4269,94', '870', '869,45', '767,7', '1980,6', '1636,04', '5108,38', '1489,13', '883,33', '1966,99', '2064,08', '1136,6', '3280', '1030,63', '652', '670', '921,58', '4550', '1128,64', '1290', '1924,4', '1715,7', '1155,06', '2370', '1789,04', '1459,34', '875,2', '1405,53', '1247,92', '4240', '805,73', '660,6', '1116,49', '715,54', '2482,72', '2595,06', '4420', '776,3', '1296,74', '3780,1', '1440', '1948,62', '2430', '2679,82', '826,77', '1881,83', '1662,1', '327,98', '3755,32', '1226,25', '1336,38', '3000', '1047,32', '2605', '963,96', '5975,04', '3637,43', '6550', '3782,39', '1330', '5180', '1720', '860,22', '2142,2', '1954,4', '1010', '2751,25', '948,58', '879', '2704,02', '3509,22', '3200', '71,71', '2493,97', '1259,43', '3910', '440', '3589,09', '699,78', '1263', '3270', '1798,49', '2940', '648,68', '1390', '457,71', '3940', '1909,16', '2320', '1113,74', '5410', '1953,6', '2287,02', '1022,67', '3250', '490', '824,02', '1192,75', '6260', '724,93', '937,79', '2070', '4060', '954,65', '2755,21', '1598,01', '630,49', '2124,5', '1090', '2390', '42,52', '3130', '1597,92', '3433,42', '2786,89', '94,89', '4884,95', '3990', '1097,62', '1231,72', '5420', '320', '589,45', '1609,47', '780', '581,15', '930,4', '5110', '4690', '1476,6', '1427,4', '918,28', '979,89', '3202,2', '872,81', '1222,06', '1180,48', '1788,46', '2419,9', '5430', '3730', '957,63', '1489,45', '1930', '1506,39', '796,59', '727,79', '3860', '950', '4290', ' ...

# %%
# можно заметить что некоторые переменные, 
# которые обозначены как строки (например PERSONAL_INCOME) на самом деле числа,
# но по какой-то (ниже увидим) причине были распознаны как строки

# %%
all_data['PERSONAL_INCOME'] = all_data['PERSONAL_INCOME'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
# причина же что использовалась запятая для разделения не целой части числа

# %%
all_data['CREDIT'] = all_data['CREDIT'].map(lambda x: x.replace(',', '.')).astype('float')
all_data['FST_PAYMENT'] = all_data['FST_PAYMENT'].map(lambda x: x.replace(',', '.')).astype('float')
all_data['LOAN_AVG_DLQ_AMT'] = all_data['LOAN_AVG_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')
all_data['LOAN_MAX_DLQ_AMT'] = all_data['LOAN_MAX_DLQ_AMT'].map(lambda x: x.replace(',', '.')).astype('float')

# %%
# запускаем повторно код и смотрим, какие столбцы с какими строковыми значениями остались

# %%
for i in all_data.columns:
    if str(all_data[i].dtype) == 'object':
        print(i)
        print(set(all_data[i]))
        print()
# Out:
# EDUCATION
# {'Среднее', 'Неоконченное высшее', 'Два и более высших образования', 'Высшее', 'Ученая степень', 'Неполное среднее', 'Среднее специальное'}
#
# MARITAL_STATUS
# {'Состою в браке', 'Разведен(а)', 'Вдовец/Вдова', 'Гражданский брак', 'Не состоял в браке'}
#
# GEN_INDUSTRY
# {nan, 'Страхование', 'Маркетинг', 'Ресторанный бизнес/Общественное питание', 'ЧОП/Детективная д-ть', 'Банк/Финансы', 'Торговля', 'Образование', 'Юридические услуги/нотариальные услуги', 'Другие сферы', 'Энергетика', 'Химия/Парфюмерия/Фармацевтика', 'Информационные услуги', 'Металлургия/Промышленность/Машиностроение', 'Салоны красоты и здоровья', 'СМИ/Реклама/PR-агенства', 'Управляющая компания', 'Недвижимость', 'Транспорт', 'Нефтегазовая промышленность', 'Государственная служба', 'Логистика', 'Развлечения/Искусство', 'Здравоохранение', 'Сельское хозяйство', 'Строительство', 'Наука', 'Подбор персонала', 'Коммунальное хоз-во/Дорожные службы', 'Информационные технологии', 'Сборочные производства', 'Туризм'}
#
# GEN_TITLE
# {nan, 'Работник сферы услуг', 'Другое', 'Служащий', 'Рабочий', 'Индивидуальный предприниматель', 'Руководитель низшего звена', 'Военнослужащий по контракту', 'Высококвалифиц. специалист', 'Специалист', 'Руководитель высшего звена', 'Партнер', 'Руководитель среднего звена'}
#
# ORG_TP_STATE
# {nan, 'Частная ком. с инос. капиталом', 'Некоммерческая организация', 'Индивидуальный предприниматель', 'Государственная комп./учреж.', 'Частная компания'}
#
# ORG_TP_FCAPITAL
# {nan, 'Без участия', 'С участием'}
#
# JOB_DIR
# {nan, 'Реклама и маркетинг', 'Вспомогательный техперсонал', 'Служба безопасности', 'Бухгалтерия, финансы, планир.', 'Участие в основ. деятельности', 'Адм-хоз. и трансп. службы', 'Снабжение и сбыт', 'Кадровая служба и секретариат', 'Юридическая служба', 'Пр-техн. обесп. и телеком.'}
#
# FAMILY_INCOME
# {'до 5000 руб.', 'свыше 50000 руб.', 'от 20000 до 50000 руб.', 'от 10000 до 20000 руб.', 'от 5000 до 10000 руб.'}
#
# REG_ADDRESS_PROVINCE
# {'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Коми-Пермяцкий АО', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Кабардино-Балкария', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Ленинградская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Московская область', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Северная Осетия', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Ямало-Ненецкий АО', 'Челябинская область', 'Эвенкийский АО', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Дагестан', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Карачаево-Черкесия', 'Хакасия', 'Агинский Бурятский АО', 'Новосибирская область', 'Псковская область', 'Саратовская область', 'Ростовская область', 'Якутия', 'Ставропольский край', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Усть-Ордынский Бурятский АО', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# FACT_ADDRESS_PROVINCE
# {'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Коми-Пермяцкий АО', 'Чечня', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Кабардино-Балкария', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Ленинградская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Московская область', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Северная Осетия', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Ямало-Ненецкий АО', 'Челябинская область', 'Эвенкийский АО', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Дагестан', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Карачаево-Черкесия', 'Хакасия', 'Агинский Бурятский АО', 'Новосибирская область', 'Псковская область', 'Саратовская область', 'Ростовская область', 'Якутия', 'Ставропольский край', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Усть-Ордынский Бурятский АО', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# POSTAL_ADDRESS_PROVINCE
# {'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Коми-Пермяцкий АО', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Кабардино-Балкария', 'Свердловская область', 'Калмыкия', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Ленинградская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Московская область', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Северная Осетия', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Ямало-Ненецкий АО', 'Челябинская область', 'Эвенкийский АО', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Дагестан', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Карачаево-Черкесия', 'Хакасия', 'Агинский Бурятский АО', 'Новосибирская область', 'Псковская область', 'Саратовская область', 'Ростовская область', 'Якутия', 'Ставропольский край', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Усть-Ордынский Бурятский АО', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# TP_PROVINCE
# {nan, 'Калининградская область', 'Липецкая область', 'Хабаровский край', 'Приморский край', 'Вологодская область', 'Рязанская область', 'Омская область', 'Алтайский край', 'Санкт-Петербург', 'Свердловская область', 'Кабардино-Балкария', 'Удмуртия', 'Татарстан', 'Тверская область', 'Новгородская область', 'Магаданская область', 'Курганская область', 'Ульяновская область', 'Самарская область', 'Москва', 'Башкирия', 'Мордовская республика', 'Брянская область', 'Калужская область', 'Ивановская область', 'Еврейская АО', 'Нижегородская область', 'Астраханская область', 'Архангельская область', 'Камчатская область', 'Горный Алтай', 'Волгоградская область', 'Кировская область', 'Челябинская область', 'Ханты-Мансийский АО', 'Оренбургская область', 'Белгородская область', 'Краснодарский край', 'Мурманская область', 'Тюменская область', 'Тамбовская область', 'Читинская область', 'Костромская область', 'Ярославская область', 'Красноярский край', 'Чувашия', 'Пензенская область', 'Орловская область', 'Тульская область', 'Томская область', 'Новосибирская область', 'Ставропольский край', 'Саратовская область', 'Ростовская область', 'Псковская область', 'Якутия', 'Смоленская область', 'Коми', 'Пермская область', 'Амурская область', 'Сахалинская область', 'Воронежская область', 'Иркутская область', 'Владимирская область', 'Марийская республика', 'Адыгея', 'Карелия', 'Курская область', 'Кемеровская область', 'Бурятия'}
#
# REGION_NM
# {nan, 'СЕВЕРО-ЗАПАДНЫЙ', 'ЦЕНТРАЛЬНЫЙ 2', 'ВОСТОЧНО-СИБИРСКИЙ', 'ЮЖНЫЙ', 'ПРИВОЛЖСКИЙ', 'ЗАПАДНО-СИБИРСКИЙ', 'ПОВОЛЖСКИЙ', 'ЦЕНТРАЛЬНЫЙ ОФИС', 'ДАЛЬНЕВОСТОЧНЫЙ', 'УРАЛЬСКИЙ', 'ЦЕНТРАЛЬНЫЙ 1'}

# %% [markdown]
# # Данные готовы, теперь вам предлагается начать решать задачу

# %%
# Есть ли пропуски в данных? что с ними сделать?

# Ваш код :-)
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30133 entries, 0 to 30132
# Data columns (total 51 columns):
# AGREEMENT_RK                  30133 non-null int64
# AGE                           30133 non-null int64
# SOCSTATUS_WORK_FL             30133 non-null int64
# SOCSTATUS_PENS_FL             30133 non-null int64
# GENDER                        30133 non-null int64
# CHILD_TOTAL                   30133 non-null int64
# DEPENDANTS                    30133 non-null int64
# EDUCATION                     30133 non-null object
# MARITAL_STATUS                30133 non-null object
# GEN_INDUSTRY                  27420 non-null object
# GEN_TITLE                     27420 non-null object
# ORG_TP_STATE                  27420 non-null object
# ORG_TP_FCAPITAL               27425 non-null object
# JOB_DIR                       27420 non-null object
# FAMILY_INCOME                 30133 non-null object
# PERSONAL_INCOME               30133 non-null float64
# REG_ADDRESS_PROVINCE          30133 non-null object
# FACT_ADDRESS_PROVINCE         30133 non-null object
# POSTAL_ADDRESS_PROVINCE       30133 non-null object
# TP_PROVINCE                   29543 non-null object
# REGION_NM                     30131 non-null object
# REG_FACT_FL                   30133 non-null int64
# FACT_POST_FL                  30133 non-null int64
# REG_POST_FL                   30133 non-null int64
# REG_FACT_POST_FL              30133 non-null int64
# REG_FACT_POST_TP_FL           30133 non-null int64
# FL_PRESENCE_FL                30133 non-null int64
# OWN_AUTO                      30133 non-null int64
# AUTO_RUS_FL                   30133 non-null int64
# HS_PRESENCE_FL                30133 non-null int64
# COT_PRESENCE_FL               30133 non-null int64
# GAR_PRESENCE_FL               30133 non-null int64
# LAND_PRESENCE_FL              30133 non-null int64
# CREDIT                        30133 non-null float64
# TERM                          30133 non-null int64
# FST_PAYMENT                   30133 non-null float64
# DL_DOCUMENT_FL                30133 non-null int64
# GPF_DOCUMENT_FL               30133 non-null int64
# FACT_LIVING_TERM              30133 non-null int64
# WORK_TIME                     27416 non-null float64
# FACT_PHONE_FL                 30133 non-null int64
# REG_PHONE_FL                  30133 non-null int64
# GEN_PHONE_FL                  30133 non-null int64
# LOAN_NUM_TOTAL                30133 non-null int64
# LOAN_NUM_CLOSED               30133 non-null int64
# LOAN_NUM_PAYM                 30133 non-null int64
# LOAN_DLQ_NUM                  30133 non-null int64
# LOAN_MAX_DLQ                  30133 non-null int64
# LOAN_AVG_DLQ_AMT              30133 non-null float64
# LOAN_MAX_DLQ_AMT              30133 non-null float64
# PREVIOUS_CARD_NUM_UTILIZED    600 non-null float64
# dtypes: float64(7), int64(31), object(13)
# memory usage: 11.7+ MB

# %%
all_data.isnull().sum()
# Out:
# AGREEMENT_RK                      0
# AGE                               0
# SOCSTATUS_WORK_FL                 0
# SOCSTATUS_PENS_FL                 0
# GENDER                            0
# CHILD_TOTAL                       0
# DEPENDANTS                        0
# EDUCATION                         0
# MARITAL_STATUS                    0
# GEN_INDUSTRY                   2713
# GEN_TITLE                      2713
# ORG_TP_STATE                   2713
# ORG_TP_FCAPITAL                2708
# JOB_DIR                        2713
# FAMILY_INCOME                     0
# PERSONAL_INCOME                   0
# REG_ADDRESS_PROVINCE              0
# FACT_ADDRESS_PROVINCE             0
# POSTAL_ADDRESS_PROVINCE           0
# TP_PROVINCE                     590
# REGION_NM                         2
# REG_FACT_FL                       0
# FACT_POST_FL                      0
# REG_POST_FL                       0
# REG_FACT_POST_FL                  0
# REG_FACT_POST_TP_FL               0
# FL_PRESENCE_FL                    0
# OWN_AUTO                          0
# AUTO_RUS_FL                       0
# HS_PRESENCE_FL                    0
# COT_PRESENCE_FL                   0
# GAR_PRESENCE_FL                   0
# LAND_PRESENCE_FL                  0
# CREDIT                            0
# TERM                              0
# FST_PAYMENT                       0
# DL_DOCUMENT_FL                    0
# GPF_DOCUMENT_FL                   0
# FACT_LIVING_TERM                  0
# WORK_TIME                      2717
# FACT_PHONE_FL                     0
# REG_PHONE_FL                      0
# GEN_PHONE_FL                      0
# LOAN_NUM_TOTAL                    0
# LOAN_NUM_CLOSED                   0
# LOAN_NUM_PAYM                     0
# LOAN_DLQ_NUM                      0
# LOAN_MAX_DLQ                      0
# LOAN_AVG_DLQ_AMT                  0
# LOAN_MAX_DLQ_AMT                  0
# PREVIOUS_CARD_NUM_UTILIZED    29533
# dtype: int64

# %%
all_data.columns
# Out:
# Index(['AGREEMENT_RK', 'AGE', 'SOCSTATUS_WORK_FL', 'SOCSTATUS_PENS_FL',
#        'GENDER', 'CHILD_TOTAL', 'DEPENDANTS', 'EDUCATION', 'MARITAL_STATUS',
#        'GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
#        'JOB_DIR', 'FAMILY_INCOME', 'PERSONAL_INCOME', 'REG_ADDRESS_PROVINCE',
#        'FACT_ADDRESS_PROVINCE', 'POSTAL_ADDRESS_PROVINCE', 'TP_PROVINCE',
#        'REGION_NM', 'REG_FACT_FL', 'FACT_POST_FL', 'REG_POST_FL',
#        'REG_FACT_POST_FL', 'REG_FACT_POST_TP_FL', 'FL_PRESENCE_FL', 'OWN_AUTO',
#        'AUTO_RUS_FL', 'HS_PRESENCE_FL', 'COT_PRESENCE_FL', 'GAR_PRESENCE_FL',
#        'LAND_PRESENCE_FL', 'CREDIT', 'TERM', 'FST_PAYMENT', 'DL_DOCUMENT_FL',
#        'GPF_DOCUMENT_FL', 'FACT_LIVING_TERM', 'WORK_TIME', 'FACT_PHONE_FL',
#        'REG_PHONE_FL', 'GEN_PHONE_FL', 'LOAN_NUM_TOTAL', 'LOAN_NUM_CLOSED',
#        'LOAN_NUM_PAYM', 'LOAN_DLQ_NUM', 'LOAN_MAX_DLQ', 'LOAN_AVG_DLQ_AMT',
#        'LOAN_MAX_DLQ_AMT', 'PREVIOUS_CARD_NUM_UTILIZED'],
#       dtype='object')

# %%
null_columns=all_data.columns[all_data.isnull().any()]
null_columns
# Out:
# Index(['GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
#        'JOB_DIR', 'TP_PROVINCE', 'REGION_NM', 'WORK_TIME',
#        'PREVIOUS_CARD_NUM_UTILIZED'],
#       dtype='object')

# %%
null_columns_1 = ['GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
       'JOB_DIR', 'TP_PROVINCE', 'REGION_NM', 'WORK_TIME']

# %%
print(all_data[all_data.isnull().any(axis=1)][null_columns].head())
# Out:
#                 GEN_INDUSTRY                    GEN_TITLE  \
# 0                   Торговля                      Рабочий
# 1                   Торговля                      Рабочий
# 2  Информационные технологии                   Специалист
# 3                Образование  Руководитель среднего звена
# 4     Государственная служба                   Специалист
#
#                      ORG_TP_STATE ORG_TP_FCAPITAL  \
# 0                Частная компания     Без участия
# 1  Индивидуальный предприниматель     Без участия
# 2    Государственная комп./учреж.     Без участия
# 3    Государственная комп./учреж.     Без участия
# 4    Государственная комп./учреж.     Без участия
#
#                          JOB_DIR           TP_PROVINCE           REGION_NM  \
# 0    Вспомогательный техперсонал  Оренбургская область          ПОВОЛЖСКИЙ
# 1  Участие в основ. деятельности   Ставропольский край               ЮЖНЫЙ
# 2  Участие в основ. деятельности     Иркутская область  ВОСТОЧНО-СИБИРСКИЙ
# 3  Участие в основ. деятельности    Ростовская область               ЮЖНЫЙ
# 4  Участие в основ. деятельности   Ставропольский край               ЮЖНЫЙ
#
#    WORK_TIME  PREVIOUS_CARD_NUM_UTILIZED
# 0       18.0                         NaN
# 1       97.0                         NaN
# 2       84.0                         NaN
# 3      168.0                         NaN
# 4      101.0                         NaN

# %%
all_data[all_data.isnull().any(axis=1)].loc[:,['GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
       'JOB_DIR', 'TP_PROVINCE', 'REGION_NM', 'WORK_TIME',
       'PREVIOUS_CARD_NUM_UTILIZED']]
# Out:
#                                     GEN_INDUSTRY  \
# 0                                       Торговля
# 1                                       Торговля
# 2                      Информационные технологии
# 3                                    Образование
# 4                         Государственная служба
# 5                                       Торговля
# 6                                   Другие сферы
# 7                             Сельское хозяйство
# 8                                Здравоохранение
# 9                                    Образование
# 10                                   Образование
# 11                                  Другие сферы
# 12     Металлургия/Промышленность/Машиностроение
# 13                        Государственная служба
# 14                        Государственная служба
# 15                                      Торговля
# 16                                           NaN
# 17           Коммунальное хоз-во/Дорожные службы
# 18                                 Строительство
# 19     Металлургия/Промышленность/Машиностроение
# 20                                   Образование
# 21                                      Торговля
# 22                                     Транспорт
# 23                               Здравоохранение
# 24     Металлургия/Промышленность/Машиностроение
# 25                                      Торговля
# 26                                      Торговля
# 27                                  Другие сферы
# 28                                  Другие сферы
# 29                                           NaN
# ...                                          ...
# 30103                     Сборочные производства
# 30104                                Образование
# 30105                                   Торговля
# 30106                                        NaN
# 30107                               Другие сферы
# 30108    Ресторанный бизнес/Общественное питание
# 30109        Коммунальное хоз-во/Дорожные службы
# 30110                            Здравоохранение
# 30111                         Сельское хозяйство
# 30112                               Другие сферы
# 30113                                Образование
# 30114                               Другие сферы
# 30115                                Образование
# 30116                                      Наука
# 30117                       ЧОП/Детективная д-ть
# 30118                                        NaN
# 30119                         Сельское хозяйство
# 30120                                Образование
# 30121                               Другие сферы
# 30122    Ресторанный бизнес/Общественное питание
# 30123                               Другие сферы
# 30124        Коммунальное хоз-во/Дорожные службы
# 30125                                   Торговля
# 30126                               Другие сферы
# 30127                                        NaN
# 30128                                  Транспорт
# 30129                                   Торговля
# 30130  Металлургия/Промышленность/Машиностроение
# 30131                                        NaN
# 30132                         Сельское хозяйство
#
#                             GEN_TITLE                    ORG_TP_STATE  \
# 0                             Рабочий                Частная компания
# 1                             Рабочий  Индивидуальный предприниматель
# 2                          Специалист    Государственная комп./учреж.
# 3         Руководитель среднего звена    Государственная комп./учреж.
# 4                          Специалист    Государственная комп./учреж.
# 5                          Специалист                Частная компания
# 6                          Специалист    Государственная комп./учреж.
# 7                             Рабочий                Частная компания
# 8          Руководитель высшего звена                Частная компания
# 9                          Специалист    Государственная комп./учреж.
# 10                           Служащий    Государственная комп./учреж.
# 11               Работник сферы услуг    Государственная комп./учреж.
# 12                            Рабочий                Частная компания
# 13                            Рабочий    Государственная комп./учреж.
# 14         Высококвалифиц. специалист    Государственная комп./учреж.
# 15     Индивидуальный предприниматель  Индивидуальный предприниматель
# 16                                NaN                             NaN
# 17                            Рабочий    Государственная комп./учреж.
# 18                            Рабочий                Частная компания
# 19                         Специалист                Частная компания
# 20                         Специалист    Государственная комп./учреж.
# 21                         Специалист                Частная компания
# 22                         Специалист    Государственная комп./учреж.
# 23                         Специалист    Государственная комп./учреж.
# 24                            Рабочий  Индивидуальный предприниматель
# 25                            Рабочий  Индивидуальный предприниматель
# 26        Руководитель среднего звена                Частная компания
# 27                         Специалист    Государственная комп./учреж.
# 28                            Рабочий                Частная компания
# 29                                NaN                             NaN
# ...                               ...                             ...
# 30103                         Рабочий                Частная компания
# 30104            Работник сферы услуг    Государственная комп./учреж.
# 30105                        Служащий                Частная компания
# 30106                             NaN                             NaN
# 30107                         Рабочий    Государственная комп./учреж.
# 30108                      Специалист                Частная компания
# 30109            Работник сферы услуг                Частная компания
# 30110                      Специалист    Государственная комп./учреж.
# 30111      Руководитель высшего звена  Индивидуальный предприниматель
# 30112                      Специалист    Государственная комп./учреж.
# 30113      Руководитель низшего звена    Государственная комп./учреж.
# 30114                      Специалист                Частная компания
# 30115                         Рабочий    Государственная комп./учреж.
# 30116                      Специалист    Государственная комп./учреж.
# 30117                         Рабочий                Частная компания
# 30118                             NaN                             NaN
# 30119                         Рабочий                Частная компания
# 30120      Руководитель высшего звена                Частная компания
# 30121                         Рабочий                Частная компания
# 30122                      Специалист                Частная компания
# 30123                      Специалист    Государственная комп./учреж.
# 30124                      Специалист    Государственная комп./учреж.
# 30121     Без участия  Участие в основ. деятельности  Нижегородская область
# 30122     Без участия  Участие в основ. деятельности        Томская область
# 30123     Без участия  Участие в основ. деятельности                 Москва
# 30124     Без участия  Участие в основ. деятельности   Астраханская область
# 30125     Без участия  Участие в основ. деятельности       Тульская область
# 30126     Без участия  Участие в основ. деятельности       Тверская область
# 30127             NaN                            NaN     Ростовская область
# 30128     Без участия  Участие в основ. деятельности                Бурятия
# 30129     Без участия  Участие в основ. деятельности    Воронежская область
# 30130     Без участия  Участие в основ. деятельности  Волгоградская область
# 30131             NaN                            NaN    Челябинская область
# 30132     Без участия  Участие в основ. деятельности   Владимирская область
#
#                 REGION_NM  WORK_TIME  PREVIOUS_CARD_NUM_UTILIZED
# 0              ПОВОЛЖСКИЙ       18.0                         NaN
# 1                   ЮЖНЫЙ       97.0                         NaN
# 2      ВОСТОЧНО-СИБИРСКИЙ       84.0                         NaN
# 3                   ЮЖНЫЙ      168.0                         NaN
# 4                   ЮЖНЫЙ      101.0                         NaN
# 5           ЦЕНТРАЛЬНЫЙ 1       40.0                         NaN
# 6           ЦЕНТРАЛЬНЫЙ 2        6.0                         NaN
# 7                   ЮЖНЫЙ        6.0                         NaN
# 8           ЦЕНТРАЛЬНЫЙ 2      156.0                         NaN
# 9                   ЮЖНЫЙ       72.0                         NaN
# 10          ЦЕНТРАЛЬНЫЙ 2      120.0                         NaN
# 11        ДАЛЬНЕВОСТОЧНЫЙ       27.0                         NaN
# 12          ЦЕНТРАЛЬНЫЙ 1       48.0                         NaN
# 13          ЦЕНТРАЛЬНЫЙ 2       72.0                         NaN
# 14        ДАЛЬНЕВОСТОЧНЫЙ      120.0                         NaN
# 15        ДАЛЬНЕВОСТОЧНЫЙ      168.0                         NaN
# 16     ВОСТОЧНО-СИБИРСКИЙ        NaN                         NaN
# 17              УРАЛЬСКИЙ        8.0                         NaN
# 18        ДАЛЬНЕВОСТОЧНЫЙ       13.0                         NaN
# 19      ЗАПАДНО-СИБИРСКИЙ       60.0                         NaN
# 20          ЦЕНТРАЛЬНЫЙ 1      192.0                         NaN
# 21          ЦЕНТРАЛЬНЫЙ 1       76.0                         NaN
# 22          ЦЕНТРАЛЬНЫЙ 2      120.0                         NaN
# 23                  ЮЖНЫЙ      108.0                         NaN
# 24                  ЮЖНЫЙ       24.0                         NaN
# 25              УРАЛЬСКИЙ       18.0                         NaN
# 26        СЕВЕРО-ЗАПАДНЫЙ       60.0                         NaN
# 27        ДАЛЬНЕВОСТОЧНЫЙ       15.0                         NaN
# 28        СЕВЕРО-ЗАПАДНЫЙ        2.0                         NaN
# 29          ЦЕНТРАЛЬНЫЙ 1        NaN                         NaN
# ...                   ...        ...                         ...
# 30103               ЮЖНЫЙ       29.0                         NaN
# 30104               ЮЖНЫЙ       36.0                         NaN
# 30105               ЮЖНЫЙ       96.0                         NaN
# 30106   ЗАПАДНО-СИБИРСКИЙ        NaN                         NaN
# 30107       ЦЕНТРАЛЬНЫЙ 1       24.0                         NaN
# 30108       ЦЕНТРАЛЬНЫЙ 2       24.0                         NaN
# 30109               ЮЖНЫЙ       36.0                         NaN
# 30110       ЦЕНТРАЛЬНЫЙ 1       35.0                         NaN
# 30111       ЦЕНТРАЛЬНЫЙ 1       36.0                         NaN
# 30112          ПОВОЛЖСКИЙ       48.0                         NaN
# 30113         ПРИВОЛЖСКИЙ      288.0                         NaN
# 30114   ЗАПАДНО-СИБИРСКИЙ       24.0                         NaN
# 30115         ПРИВОЛЖСКИЙ       48.0                         NaN
# 30116   ЗАПАДНО-СИБИРСКИЙ      132.0                         NaN
# 30117               ЮЖНЫЙ       24.0                         NaN
# 30118          ПОВОЛЖСКИЙ        NaN                         NaN
# 30119          ПОВОЛЖСКИЙ      456.0                         NaN
# 30120               ЮЖНЫЙ       24.0                         NaN
# 30121         ПРИВОЛЖСКИЙ      300.0                         NaN
# 30122   ЗАПАДНО-СИБИРСКИЙ       60.0                         NaN
# 30123    ЦЕНТРАЛЬНЫЙ ОФИС       96.0                         NaN
# 30124               ЮЖНЫЙ      168.0                         NaN
# 30125       ЦЕНТРАЛЬНЫЙ 1        6.0                         NaN
# 30126       ЦЕНТРАЛЬНЫЙ 1       72.0                         NaN
# 30127               ЮЖНЫЙ        NaN                         NaN
# 30128  ВОСТОЧНО-СИБИРСКИЙ       72.0                         NaN
# 30129       ЦЕНТРАЛЬНЫЙ 2       18.0                         NaN
# 30130               ЮЖНЫЙ       15.0                         NaN
# 30131           УРАЛЬСКИЙ        NaN                         NaN
# 30132       ЦЕНТРАЛЬНЫЙ 2       36.0                         NaN
#
# [29578 rows x 9 columns]

# %%
len(all_data[pd.isnull(all_data['ORG_TP_FCAPITAL'])].loc[:,['GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
       'JOB_DIR', 'TP_PROVINCE', 'REGION_NM', 'WORK_TIME','PREVIOUS_CARD_NUM_UTILIZED']])
# Out:
# 2708

# %%
all_data[pd.isnull(all_data['GEN_INDUSTRY'])].loc[:,['GEN_INDUSTRY', 'GEN_TITLE', 'ORG_TP_STATE', 'ORG_TP_FCAPITAL',
       'JOB_DIR', 'TP_PROVINCE', 'REGION_NM', 'WORK_TIME','PREVIOUS_CARD_NUM_UTILIZED']].count()
# Out:
# GEN_INDUSTRY                     0
# GEN_TITLE                        0
# ORG_TP_STATE                     0
# ORG_TP_FCAPITAL                  6
# JOB_DIR                          0
# TP_PROVINCE                   2697
# REGION_NM                     2713
# WORK_TIME                        0
# PREVIOUS_CARD_NUM_UTILIZED      42
# dtype: int64

# %%
# Как поступить со строковыми переменными?

# Ваш код :-)

# %%
# В итоге должны получиться данные без пропусков и только числовые

# %%
# Вновь разделите на train и test (не мешая)

# Ваш код :-)

# %%
# Сделать hold-out sampling на train выборке
from sklearn.cross_validation import train_test_split

# test_size=0.3, random_state=42

# Ваш код :-)

# %%
# Попробовать следующие "черные ящики": интерфейс одинаковый 
#     fit, 
#     predict, 
#     predict_proba

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# Ваш код :-)

# %%
# Посчитать метрики стандартные
# accuracy, precision, recall

# Ваш код :-)

# %%
# Визуалищировать эти метрики всех моделей на одном графике (чтоб визуально посмотреть)

# Ваш код :-)

# %%
# Потроить roc-кривые всех можелей на одном графике
# Вывести roc_auc каждой моделе

# Ваш код :-)

# %%
from sklearn.cross_validation import cross_val_score
# Сделать k-fold (10 фолдов) кросс-валидацию каждой модели
# И посчитать средний roc_auc

# Ваш код :-)

# %%
# Взять лучшую модель и сделать predict (с вероятностями (!!!)) для test выборки

# Ваш код :-)
